# %% [markdown]
# <a href="https://colab.research.google.com/github/chuan137/egohands/blob/master/grocery/grocery_categories_v06_c.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Note
#
# __Description__ more categories for training.
#
# __Update__

# %% [markdown]
# ## Training Details
#
# **Train data**
# * 5 categories: BEANS, CAKE, CANDY, MILK, PASTA
# * image size 224
#
# **Architecture**
# * **With** fully connected layer
# * prediction layer with L2 regularizer
#
# **Hyper parameters**
# * softmax layer with regularizer, weight = 0.0001
# * optimizer Adam, learning rate 0.0001

# %% [markdown]
# ## Prepare

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cp /content/drive/My\ Drive/freiburg_groceries_dataset.zip .
# !unzip -q freiburg_groceries_dataset.zip

# %% [markdown]
# ## Load Data

# %%
# %tensorflow_version 2.x
import tensorflow as tf
print(tf.__version__)
# Out:
# TensorFlow 2.x selected.
# 2.0.0

# %% [markdown]
# * split train and test images

# %%
import os
import random
import pandas as pd

def find_images(dpath, subdir=''):
    """ return [](filepath, label) """
    images = []
    if os.path.isdir(os.path.join(dpath, subdir)):
        for filename in os.listdir(os.path.join(dpath, subdir)):
            filepath = os.path.join(subdir, filename)
            images.append(filepath)
    return images


def split_images(images, splits):
    'shuffle and split images[] to train[], validation and test[]'
    if type(splits) not in (list, tuple):
        raise TypeError("splits must be list or tuple")
    elif abs(sum(splits) - 1.0) > 0.000001:
        raise ValueError("sum of splits should be 1.0")
    elif len(splits) not in (2, 3):
        raise ValueError("splits should have 2 or 3 elements") 
    random.shuffle(images)
    n = len(images)
    if len(splits) == 2:
        n1, _ = [round(x*n) for x in splits]
        print(n1)
        return images[:n1], images[n1:]
    else:
        n1, n2, _ = [round(x*n) for x in splits]
        return images[:n1], images[n1:n1+n2], images[n1+n2:]

all_classes = next(os.walk('images'))[1]

train = []
val = []
test = []
splits = (0.8, 0.1, 0.1)
for cl in all_classes:
    images = find_images('images', cl)
    tr, v, te = split_images(images, splits)
    train += zip(tr, [cl] * len(tr))
    val += zip(v, [cl] * len(v))
    test += zip(te, [cl] * len(te))

train_df = pd.DataFrame(train, columns=['filename', 'class'])
val_df = pd.DataFrame(val, columns=['filename', 'class'])
test_df = pd.DataFrame(test, columns=['filename', 'class'])

# %% [markdown]
# * create data generator for training

# %%
IMAGE_SIZE = 224
BATCH_SIZE = 32
seed = 76

classes = ['BEANS', 'CAKE', 'CANDY', 'MILK', 'PASTA']
n_classes = len(classes)
classmap = {c: i for i, c in enumerate(classes)}
img_shape = (IMAGE_SIZE, IMAGE_SIZE, 3)

# %%
import os
labels_count = dict()
for img_class in classes:
    labels_count[img_class] = len(os.listdir('images/' + img_class))
total_count = sum(labels_count.values())
class_weights = {cls: total_count / count for cls, count in 
                 enumerate(labels_count.values())}
class_weights
# Out:
# {0: 7.375,
#  1: 6.229813664596273,
#  2: 2.696236559139785,
#  3: 6.191358024691358,
#  4: 5.8313953488372094}

# %%
train_dataset = train_df[train_df['class'].isin(classes)]
train_filenames = train_dataset['filename'].tolist()
train_labels = train_dataset['class'].tolist()
train_labels = [classmap[l] for l in train_labels]
train_labels = tf.keras.utils.to_categorical(train_labels, num_classes=n_classes)

val_dataset = val_df[val_df['class'].isin(classes)]
val_filenames = val_dataset['filename'].tolist()
val_labels = val_dataset['class'].tolist()
val_labels = [classmap[l] for l in val_labels]
val_labels = tf.keras.utils.to_categorical(val_labels, num_classes=n_classes)

test_dataset = test_df[test_df['class'].isin(classes)]
test_filenames = test_dataset['filename'].tolist()
test_labels = test_dataset['class'].tolist()
test_labels = [classmap[l] for l in test_labels]
test_labels = tf.keras.utils.to_categorical(test_labels, num_classes=n_classes)

len(train_filenames), len(val_filenames), len(test_filenames)
# Out:
# (804, 100, 99)

# %%
# Function to load and preprocess each image
def _parse_fn(filename, label):
    filename = 'images/' + filename
    img = tf.io.read_file(filename)
    img = tf.image.decode_png(img)
    img = (tf.cast(img, tf.float32)/127.5) - 1
    # img = tf.cast(img, tf.float32)/255.0
    img = tf.image.resize(img, (IMAGE_SIZE, IMAGE_SIZE))
    return img, label

train_data = tf.data.Dataset.from_tensor_slices(
  (tf.constant(train_filenames), tf.constant(train_labels))
)

val_data = tf.data.Dataset.from_tensor_slices(
  (tf.constant(val_filenames), tf.constant(val_labels))
)

test_data = tf.data.Dataset.from_tensor_slices(
    (tf.constant(test_filenames), tf.constant(test_labels))
)

train_data = (train_data.shuffle(buffer_size=len(train_filenames))
             .map(_parse_fn)
             .batch(BATCH_SIZE)
)

val_data = (val_data.shuffle(buffer_size=len(val_filenames))
            .map(_parse_fn)
            .batch(BATCH_SIZE)
)

test_data = (test_data.map(_parse_fn))

n_train = len(train_filenames)
n_val = len(val_filenames)
n_train, n_val
# Out:
# (804, 100)

# %% [markdown]
#  * build train model

# %%
import tensorflow as tf
from tensorflow.keras import regularizers

w_l2 = 0.0001

# Pre-trained model with MobileNetV2
base_model = tf.keras.applications.MobileNetV2(
    input_shape=img_shape,
    include_top=False,
    weights='imagenet'
)

# Freeze the pre-trained model weights
base_model.trainable = False

# Trainable classification head
maxpool_layer = tf.keras.layers.GlobalMaxPooling2D()
fc_layer_1 = tf.keras.layers.Dense(2048, activation='relu')

# Prediction with L2 regularizer
prediction_layer = tf.keras.layers.Dense(
    n_classes, 
    kernel_regularizer=regularizers.l2(w_l2), 
    activation='softmax')

# Layer classification head with feature detector
model = tf.keras.Sequential([
    base_model,
    maxpool_layer,
    fc_layer_1,
    prediction_layer
])

model.summary()
# Out:
# Downloading data from https://github.com/JonathanCMitchell/mobilenet_v2_keras/releases/download/v1.1/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenetv2_1.00_224 (Model) (None, 7, 7, 1280)        2257984
# _________________________________________________________________
# global_max_pooling2d (Global (None, 1280)              0
# _________________________________________________________________
# dense (Dense)                (None, 2048)              2623488
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 10245
# =================================================================
# Total params: 4,891,717
# Trainable params: 2,633,733
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
epochs = 3000
learning_rate = 0.0001

# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate), 
              loss='categorical_crossentropy',
              metrics=['accuracy']
)

steps_per_epoch = round(n_train/BATCH_SIZE)
validation_steps = round(n_val/BATCH_SIZE)

hist = model.fit(train_data.repeat(), 
                 epochs=epochs,
                 steps_per_epoch=steps_per_epoch,
                 validation_data=val_data.repeat(),
                 validation_steps=validation_steps,
                 class_weight=class_weights)
# Out:
# Train for 25 steps, validate for 3 steps
# Epoch 1/3000
# 25/25 [==============================] - 14s 549ms/step - loss: 3.4707 - accuracy: 0.3900 - val_loss: 1.8377 - val_accuracy: 0.4896
# Epoch 2/3000
# 25/25 [==============================] - 6s 223ms/step - loss: 1.0674 - accuracy: 0.6943 - val_loss: 1.2086 - val_accuracy: 0.5729
# Epoch 3/3000
# 25/25 [==============================] - 5s 203ms/step - loss: 0.5555 - accuracy: 0.8096 - val_loss: 1.7130 - val_accuracy: 0.4688
# Epoch 4/3000
# 25/25 [==============================] - 5s 204ms/step - loss: 0.5308 - accuracy: 0.8264 - val_loss: 1.3487 - val_accuracy: 0.5938
# Epoch 5/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.4362 - accuracy: 0.8329 - val_loss: 1.5271 - val_accuracy: 0.5729
# Epoch 6/3000
# 25/25 [==============================] - 5s 207ms/step - loss: 0.4302 - accuracy: 0.8536 - val_loss: 1.4911 - val_accuracy: 0.5625
# Epoch 7/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.3228 - accuracy: 0.8886 - val_loss: 1.5306 - val_accuracy: 0.5729
# Epoch 8/3000
# 25/25 [==============================] - 5s 201ms/step - loss: 0.4753 - accuracy: 0.8549 - val_loss: 1.4140 - val_accuracy: 0.6354
# Epoch 9/3000
# 25/25 [==============================] - 5s 200ms/step - loss: 0.4889 - accuracy: 0.8484 - val_loss: 1.6393 - val_accuracy: 0.6250
# Epoch 10/3000
# 25/25 [==============================] - 5s 201ms/step - loss: 0.4027 - accuracy: 0.8601 - val_loss: 1.1275 - val_accuracy: 0.6562
# Epoch 11/3000
# 25/25 [==============================] - 5s 203ms/step - loss: 0.2519 - accuracy: 0.9171 - val_loss: 1.8902 - val_accuracy: 0.5417
# Epoch 12/3000
# 25/25 [==============================] - 5s 201ms/step - loss: 0.1279 - accuracy: 0.9598 - val_loss: 1.5130 - val_accuracy: 0.5729
# Epoch 13/3000
# 25/25 [==============================] - 5s 203ms/step - loss: 0.1783 - accuracy: 0.9469 - val_loss: 1.5231 - val_accuracy: 0.5833
# Epoch 14/3000
# 25/25 [==============================] - 5s 202ms/step - loss: 0.1777 - accuracy: 0.9378 - val_loss: 1.2528 - val_accuracy: 0.6354
# Epoch 15/3000
# 25/25 [==============================] - 5s 204ms/step - loss: 0.1521 - accuracy: 0.9573 - val_loss: 1.7028 - val_accuracy: 0.5833
# Epoch 16/3000
# 25/25 [==============================] - 5s 208ms/step - loss: 0.1239 - accuracy: 0.9598 - val_loss: 1.4688 - val_accuracy: 0.6042
# Epoch 17/3000
# 25/25 [==============================] - 5s 202ms/step - loss: 0.2896 - accuracy: 0.9391 - val_loss: 2.0143 - val_accuracy: 0.5312
# Epoch 18/3000
# 25/25 [==============================] - 5s 202ms/step - loss: 0.5245 - accuracy: 0.8912 - val_loss: 3.2064 - val_accuracy: 0.4896
# Epoch 19/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.2864 - accuracy: 0.9067 - val_loss: 1.6582 - val_accuracy: 0.6146
# Epoch 20/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.2001 - accuracy: 0.9275 - val_loss: 1.7186 - val_accuracy: 0.5729
# Epoch 21/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.0701 - accuracy: 0.9780 - val_loss: 2.2266 - val_accuracy: 0.5521
# Epoch 22/3000
# 25/25 [==============================] - 5s 204ms/step - loss: 0.1350 - accuracy: 0.9598 - val_loss: 3.3638 - val_accuracy: 0.5000
# Epoch 23/3000
# 25/25 [==============================] - 5s 204ms/step - loss: 0.4932 - accuracy: 0.8705 - val_loss: 5.1995 - val_accuracy: 0.5104
# Epoch 24/3000
# 25/25 [==============================] - 5s 203ms/step - loss: 0.5185 - accuracy: 0.8795 - val_loss: 4.2440 - val_accuracy: 0.2917
# Epoch 25/3000
# 25/25 [==============================] - 5s 203ms/step - loss: 0.5498 - accuracy: 0.8782 - val_loss: 1.3421 - val_accuracy: 0.6354
# Epoch 26/3000
# 25/25 [==============================] - 5s 200ms/step - loss: 0.3357 - accuracy: 0.8873 - val_loss: 2.6721 - val_accuracy: 0.5417
# Epoch 27/3000
# 25/25 [==============================] - 5s 211ms/step - loss: 0.0999 - accuracy: 0.9625 - val_loss: 2.1713 - val_accuracy: 0.5833
# Epoch 28/3000
# 25/25 [==============================] - 5s 207ms/step - loss: 0.0446 - accuracy: 0.9858 - val_loss: 1.9465 - val_accuracy: 0.5625
# Epoch 29/3000
# 25/25 [==============================] - 5s 203ms/step - loss: 0.3103 - accuracy: 0.9197 - val_loss: 1.7822 - val_accuracy: 0.5625
# Epoch 30/3000
# 25/25 [==============================] - 5s 204ms/step - loss: 0.1523 - accuracy: 0.9767 - val_loss: 2.3277 - val_accuracy: 0.5729
# Epoch 31/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.0290 - accuracy: 0.9935 - val_loss: 1.8107 - val_accuracy: 0.6042
# Epoch 32/3000
# 25/25 [==============================] - 5s 204ms/step - loss: 0.0982 - accuracy: 0.9741 - val_loss: 1.8334 - val_accuracy: 0.5833
# Epoch 33/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.1163 - accuracy: 0.9767 - val_loss: 1.7629 - val_accuracy: 0.6250
# Epoch 34/3000
# 25/25 [==============================] - 5s 203ms/step - loss: 0.9450 - accuracy: 0.8446 - val_loss: 1.9734 - val_accuracy: 0.5833
# Epoch 35/3000
# 25/25 [==============================] - 5s 202ms/step - loss: 0.2051 - accuracy: 0.9326 - val_loss: 1.6885 - val_accuracy: 0.6354
# Epoch 36/3000
# 25/25 [==============================] - 5s 202ms/step - loss: 0.1639 - accuracy: 0.9767 - val_loss: 2.3909 - val_accuracy: 0.5833
# Epoch 37/3000
# 25/25 [==============================] - 5s 201ms/step - loss: 0.0551 - accuracy: 0.9819 - val_loss: 2.0018 - val_accuracy: 0.5938
# Epoch 38/3000
# 25/25 [==============================] - 5s 202ms/step - loss: 0.0423 - accuracy: 0.9883 - val_loss: 2.1427 - val_accuracy: 0.6042
# Epoch 39/3000
# 25/25 [==============================] - 5s 203ms/step - loss: 0.1881 - accuracy: 0.9417 - val_loss: 2.1479 - val_accuracy: 0.6354
# Epoch 40/3000
# 25/25 [==============================] - 5s 204ms/step - loss: 0.1465 - accuracy: 0.9521 - val_loss: 3.0094 - val_accuracy: 0.5208
# Epoch 41/3000
# 25/25 [==============================] - 5s 204ms/step - loss: 0.1099 - accuracy: 0.9650 - val_loss: 1.7725 - val_accuracy: 0.6146
# Epoch 42/3000
# 25/25 [==============================] - 5s 202ms/step - loss: 0.0767 - accuracy: 0.9754 - val_loss: 1.8888 - val_accuracy: 0.5729
# Epoch 43/3000
# 25/25 [==============================] - 5s 203ms/step - loss: 0.1685 - accuracy: 0.9702 - val_loss: 1.9444 - val_accuracy: 0.6146
# Epoch 44/3000
# 25/25 [==============================] - 5s 202ms/step - loss: 0.0970 - accuracy: 0.9676 - val_loss: 2.4734 - val_accuracy: 0.5938
# Epoch 45/3000
# 25/25 [==============================] - 5s 202ms/step - loss: 0.3065 - accuracy: 0.9339 - val_loss: 1.6936 - val_accuracy: 0.5938
# Epoch 46/3000
# 25/25 [==============================] - 5s 202ms/step - loss: 0.1286 - accuracy: 0.9702 - val_loss: 1.8164 - val_accuracy: 0.6042
# Epoch 47/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.0126 - accuracy: 0.9974 - val_loss: 1.7923 - val_accuracy: 0.6250
# Epoch 48/3000
# 25/25 [==============================] - 5s 207ms/step - loss: 0.0152 - accuracy: 0.9974 - val_loss: 1.5274 - val_accuracy: 0.6667
# Epoch 49/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.0215 - accuracy: 0.9974 - val_loss: 1.8402 - val_accuracy: 0.5938
# Epoch 50/3000
# 25/25 [==============================] - 5s 204ms/step - loss: 0.0373 - accuracy: 0.9870 - val_loss: 1.6742 - val_accuracy: 0.6458
# Epoch 51/3000
# 25/25 [==============================] - 5s 202ms/step - loss: 0.0965 - accuracy: 0.9870 - val_loss: 2.0244 - val_accuracy: 0.6250
# Epoch 52/3000
# 25/25 [==============================] - 5s 201ms/step - loss: 0.3268 - accuracy: 0.9223 - val_loss: 2.1562 - val_accuracy: 0.6354
# Epoch 53/3000
# 25/25 [==============================] - 5s 211ms/step - loss: 0.2929 - accuracy: 0.9175 - val_loss: 2.3067 - val_accuracy: 0.5833
# Epoch 54/3000
# 25/25 [==============================] - 5s 207ms/step - loss: 0.0426 - accuracy: 0.9832 - val_loss: 2.1722 - val_accuracy: 0.6354
# Epoch 55/3000
# 25/25 [==============================] - 5s 204ms/step - loss: 0.4768 - accuracy: 0.9210 - val_loss: 1.6026 - val_accuracy: 0.6458
# Epoch 56/3000
# 25/25 [==============================] - 5s 201ms/step - loss: 0.0571 - accuracy: 0.9793 - val_loss: 1.5875 - val_accuracy: 0.6771
# Epoch 57/3000
# 25/25 [==============================] - 5s 196ms/step - loss: 0.0520 - accuracy: 0.9819 - val_loss: 1.6419 - val_accuracy: 0.6458
# Epoch 58/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.0178 - accuracy: 0.9987 - val_loss: 2.1117 - val_accuracy: 0.6042
# Epoch 59/3000
# 25/25 [==============================] - 5s 204ms/step - loss: 0.0340 - accuracy: 0.9896 - val_loss: 1.6699 - val_accuracy: 0.6458
# Epoch 60/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.0459 - accuracy: 0.9819 - val_loss: 1.6544 - val_accuracy: 0.6562
# Epoch 61/3000
# 25/25 [==============================] - 5s 204ms/step - loss: 0.0099 - accuracy: 0.9987 - val_loss: 1.7122 - val_accuracy: 0.6562
# Epoch 62/3000
# 25/25 [==============================] - 5s 203ms/step - loss: 0.0231 - accuracy: 0.9935 - val_loss: 2.1747 - val_accuracy: 0.6146
# Epoch 63/3000
# 25/25 [==============================] - 5s 200ms/step - loss: 0.0175 - accuracy: 0.9935 - val_loss: 2.1131 - val_accuracy: 0.5521
# Epoch 64/3000
# 25/25 [==============================] - 5s 203ms/step - loss: 0.0291 - accuracy: 0.9870 - val_loss: 1.7436 - val_accuracy: 0.6250
# Epoch 65/3000
# 25/25 [==============================] - 5s 204ms/step - loss: 0.0703 - accuracy: 0.9845 - val_loss: 2.6362 - val_accuracy: 0.5938
# Epoch 66/3000
# 25/25 [==============================] - 5s 204ms/step - loss: 0.0835 - accuracy: 0.9832 - val_loss: 1.7202 - val_accuracy: 0.6250
# Epoch 67/3000
# 25/25 [==============================] - 5s 209ms/step - loss: 0.0334 - accuracy: 0.9909 - val_loss: 1.7898 - val_accuracy: 0.5938
# Epoch 68/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.2537 - accuracy: 0.9365 - val_loss: 3.1763 - val_accuracy: 0.5104
# Epoch 69/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.1914 - accuracy: 0.9611 - val_loss: 2.6370 - val_accuracy: 0.5104
# Epoch 70/3000
# 25/25 [==============================] - 5s 203ms/step - loss: 0.0731 - accuracy: 0.9754 - val_loss: 2.1765 - val_accuracy: 0.5729
# Epoch 71/3000
# 25/25 [==============================] - 5s 204ms/step - loss: 0.1461 - accuracy: 0.9547 - val_loss: 2.2939 - val_accuracy: 0.6146
# Epoch 72/3000
# 25/25 [==============================] - 5s 203ms/step - loss: 0.1222 - accuracy: 0.9573 - val_loss: 2.5960 - val_accuracy: 0.6042
# Epoch 73/3000
# 25/25 [==============================] - 5s 202ms/step - loss: 0.3995 - accuracy: 0.9352 - val_loss: 3.6162 - val_accuracy: 0.6146
# Epoch 74/3000
# 25/25 [==============================] - 5s 202ms/step - loss: 0.2849 - accuracy: 0.9249 - val_loss: 2.0323 - val_accuracy: 0.6250
# Epoch 75/3000
# 25/25 [==============================] - 5s 204ms/step - loss: 0.0757 - accuracy: 0.9819 - val_loss: 1.7944 - val_accuracy: 0.6146
# Epoch 76/3000
# 25/25 [==============================] - 5s 207ms/step - loss: 0.0472 - accuracy: 0.9845 - val_loss: 2.1105 - val_accuracy: 0.6250
# Epoch 77/3000
# 25/25 [==============================] - 5s 208ms/step - loss: 0.0179 - accuracy: 0.9961 - val_loss: 2.0868 - val_accuracy: 0.6250
# Epoch 78/3000
# 25/25 [==============================] - 5s 203ms/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 2.1586 - val_accuracy: 0.6146
# Epoch 79/3000
# 25/25 [==============================] - 5s 215ms/step - loss: 0.0168 - accuracy: 0.9950 - val_loss: 2.0863 - val_accuracy: 0.6458
# Epoch 80/3000
# 25/25 [==============================] - 5s 212ms/step - loss: 0.0905 - accuracy: 0.9728 - val_loss: 1.6245 - val_accuracy: 0.6667
# Epoch 81/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.0091 - accuracy: 0.9974 - val_loss: 1.9121 - val_accuracy: 0.6354
# Epoch 82/3000
# 25/25 [==============================] - 5s 203ms/step - loss: 0.3221 - accuracy: 0.9288 - val_loss: 1.6865 - val_accuracy: 0.6354
# Epoch 83/3000
# 25/25 [==============================] - 5s 201ms/step - loss: 0.1009 - accuracy: 0.9793 - val_loss: 2.8206 - val_accuracy: 0.5417
# Epoch 84/3000
# 25/25 [==============================] - 5s 203ms/step - loss: 0.0331 - accuracy: 0.9870 - val_loss: 2.0342 - val_accuracy: 0.6354
# Epoch 85/3000
# 25/25 [==============================] - 5s 202ms/step - loss: 0.3430 - accuracy: 0.9067 - val_loss: 3.1223 - val_accuracy: 0.5521
# Epoch 86/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 1.3731 - accuracy: 0.8368 - val_loss: 2.5058 - val_accuracy: 0.5000
# Epoch 87/3000
# 25/25 [==============================] - 5s 208ms/step - loss: 0.5686 - accuracy: 0.8873 - val_loss: 1.9388 - val_accuracy: 0.6042
# Epoch 88/3000
# 25/25 [==============================] - 5s 209ms/step - loss: 0.0576 - accuracy: 0.9819 - val_loss: 2.0016 - val_accuracy: 0.6250
# Epoch 89/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.0511 - accuracy: 0.9845 - val_loss: 2.0563 - val_accuracy: 0.6042
# Epoch 90/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.2191 - accuracy: 0.9521 - val_loss: 2.3828 - val_accuracy: 0.5938
# Epoch 91/3000
# 25/25 [==============================] - 5s 202ms/step - loss: 0.0783 - accuracy: 0.9780 - val_loss: 1.9329 - val_accuracy: 0.6458
# Epoch 92/3000
# 25/25 [==============================] - 5s 202ms/step - loss: 0.1290 - accuracy: 0.9702 - val_loss: 1.7913 - val_accuracy: 0.6146
# Epoch 93/3000
# 25/25 [==============================] - 5s 202ms/step - loss: 0.0602 - accuracy: 0.9780 - val_loss: 2.4932 - val_accuracy: 0.6042
# Epoch 94/3000
# 25/25 [==============================] - 5s 201ms/step - loss: 0.0895 - accuracy: 0.9780 - val_loss: 1.8749 - val_accuracy: 0.6354
# Epoch 95/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.0544 - accuracy: 0.9832 - val_loss: 2.0825 - val_accuracy: 0.6250
# Epoch 96/3000
# 25/25 [==============================] - 5s 202ms/step - loss: 0.0862 - accuracy: 0.9832 - val_loss: 2.7004 - val_accuracy: 0.6146
# Epoch 97/3000
# 25/25 [==============================] - 5s 203ms/step - loss: 0.1213 - accuracy: 0.9702 - val_loss: 3.1931 - val_accuracy: 0.5833
# Epoch 98/3000
# 25/25 [==============================] - 5s 203ms/step - loss: 0.0445 - accuracy: 0.9819 - val_loss: 2.1294 - val_accuracy: 0.6250
# Epoch 99/3000
# 25/25 [==============================] - 5s 202ms/step - loss: 0.0126 - accuracy: 0.9974 - val_loss: 1.9060 - val_accuracy: 0.6042
# Epoch 100/3000
# 25/25 [==============================] - 5s 201ms/step - loss: 0.0109 - accuracy: 0.9987 - val_loss: 2.4169 - val_accuracy: 0.5521
# Epoch 101/3000
# 25/25 [==============================] - 5s 201ms/step - loss: 0.0112 - accuracy: 0.9987 - val_loss: 2.2515 - val_accuracy: 0.5833
# Epoch 102/3000
# 25/25 [==============================] - 5s 200ms/step - loss: 0.0054 - accuracy: 0.9987 - val_loss: 2.1979 - val_accuracy: 0.5938
# Epoch 103/3000
# 25/25 [==============================] - 5s 203ms/step - loss: 0.0194 - accuracy: 0.9948 - val_loss: 1.9253 - val_accuracy: 0.6250
# Epoch 104/3000
# 25/25 [==============================] - 5s 199ms/step - loss: 0.0218 - accuracy: 0.9935 - val_loss: 2.7148 - val_accuracy: 0.5625
# Epoch 105/3000
# 25/25 [==============================] - 5s 213ms/step - loss: 0.0100 - accuracy: 0.9987 - val_loss: 2.0608 - val_accuracy: 0.5833
# Epoch 106/3000
# 25/25 [==============================] - 5s 212ms/step - loss: 0.0134 - accuracy: 0.9974 - val_loss: 2.1900 - val_accuracy: 0.6042
# Epoch 107/3000
# 25/25 [==============================] - 5s 207ms/step - loss: 0.1479 - accuracy: 0.9728 - val_loss: 2.3644 - val_accuracy: 0.6042
# Epoch 108/3000
# 25/25 [==============================] - 5s 207ms/step - loss: 0.0121 - accuracy: 0.9974 - val_loss: 2.2475 - val_accuracy: 0.5938
# Epoch 109/3000
# 25/25 [==============================] - 5s 203ms/step - loss: 0.0098 - accuracy: 0.9974 - val_loss: 2.2565 - val_accuracy: 0.6354
# Epoch 110/3000
# 25/25 [==============================] - 5s 204ms/step - loss: 0.0616 - accuracy: 0.9780 - val_loss: 2.9873 - val_accuracy: 0.5521
# Epoch 111/3000
# 25/25 [==============================] - 5s 202ms/step - loss: 0.0402 - accuracy: 0.9922 - val_loss: 1.8802 - val_accuracy: 0.6354
# Epoch 112/3000
# 25/25 [==============================] - 5s 201ms/step - loss: 0.0073 - accuracy: 0.9987 - val_loss: 2.1173 - val_accuracy: 0.6146
# Epoch 113/3000
# 25/25 [==============================] - 5s 203ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 2.2315 - val_accuracy: 0.5938
# Epoch 114/3000
# 25/25 [==============================] - 5s 204ms/step - loss: 0.0298 - accuracy: 0.9909 - val_loss: 1.9693 - val_accuracy: 0.6250
# Epoch 115/3000
# 25/25 [==============================] - 5s 196ms/step - loss: 0.3010 - accuracy: 0.9339 - val_loss: 2.5930 - val_accuracy: 0.5625
# Epoch 116/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.1175 - accuracy: 0.9767 - val_loss: 2.6065 - val_accuracy: 0.5417
# Epoch 117/3000
# 25/25 [==============================] - 5s 211ms/step - loss: 0.0267 - accuracy: 0.9922 - val_loss: 2.3859 - val_accuracy: 0.5938
# Epoch 118/3000
# 25/25 [==============================] - 5s 203ms/step - loss: 0.0130 - accuracy: 0.9948 - val_loss: 2.0497 - val_accuracy: 0.6458
# Epoch 119/3000
# 25/25 [==============================] - 5s 201ms/step - loss: 0.0143 - accuracy: 0.9974 - val_loss: 2.1317 - val_accuracy: 0.6250
# Epoch 120/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.0103 - accuracy: 0.9987 - val_loss: 2.2470 - val_accuracy: 0.5938
# Epoch 121/3000
# 25/25 [==============================] - 5s 197ms/step - loss: 0.0695 - accuracy: 0.9845 - val_loss: 3.0564 - val_accuracy: 0.5312
# Epoch 122/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.0762 - accuracy: 0.9793 - val_loss: 3.4591 - val_accuracy: 0.5521
# Epoch 123/3000
# 25/25 [==============================] - 5s 196ms/step - loss: 0.0742 - accuracy: 0.9741 - val_loss: 2.5635 - val_accuracy: 0.5625
# Epoch 124/3000
# 25/25 [==============================] - 5s 204ms/step - loss: 0.0681 - accuracy: 0.9858 - val_loss: 2.3704 - val_accuracy: 0.5938
# Epoch 125/3000
# 25/25 [==============================] - 5s 203ms/step - loss: 0.1349 - accuracy: 0.9676 - val_loss: 1.7919 - val_accuracy: 0.6354
# Epoch 126/3000
# 25/25 [==============================] - 5s 204ms/step - loss: 0.0844 - accuracy: 0.9767 - val_loss: 3.7768 - val_accuracy: 0.5312
# Epoch 127/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.0863 - accuracy: 0.9676 - val_loss: 3.2885 - val_accuracy: 0.5833
# Epoch 128/3000
# 25/25 [==============================] - 5s 207ms/step - loss: 0.1240 - accuracy: 0.9832 - val_loss: 3.8661 - val_accuracy: 0.5417
# Epoch 129/3000
# 25/25 [==============================] - 5s 203ms/step - loss: 0.1557 - accuracy: 0.9650 - val_loss: 2.7711 - val_accuracy: 0.5208
# Epoch 130/3000
# 25/25 [==============================] - 5s 200ms/step - loss: 0.0622 - accuracy: 0.9754 - val_loss: 1.8059 - val_accuracy: 0.6146
# Epoch 131/3000
# 25/25 [==============================] - 5s 211ms/step - loss: 0.0371 - accuracy: 0.9887 - val_loss: 2.6183 - val_accuracy: 0.5833
# Epoch 132/3000
# 25/25 [==============================] - 5s 207ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 2.0114 - val_accuracy: 0.5833
# Epoch 133/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.0108 - accuracy: 0.9974 - val_loss: 2.2738 - val_accuracy: 0.5729
# Epoch 134/3000
# 25/25 [==============================] - 5s 200ms/step - loss: 0.2616 - accuracy: 0.9197 - val_loss: 1.5915 - val_accuracy: 0.6667
# Epoch 135/3000
# 25/25 [==============================] - 5s 208ms/step - loss: 0.2309 - accuracy: 0.9417 - val_loss: 2.5705 - val_accuracy: 0.6042
# Epoch 136/3000
# 25/25 [==============================] - 5s 199ms/step - loss: 0.2069 - accuracy: 0.9495 - val_loss: 2.4242 - val_accuracy: 0.6042
# Epoch 137/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.1031 - accuracy: 0.9845 - val_loss: 2.8269 - val_accuracy: 0.5729
# Epoch 138/3000
# 25/25 [==============================] - 5s 197ms/step - loss: 0.2141 - accuracy: 0.9547 - val_loss: 3.1791 - val_accuracy: 0.5521
# Epoch 139/3000
# 25/25 [==============================] - 5s 203ms/step - loss: 0.2060 - accuracy: 0.9611 - val_loss: 1.9344 - val_accuracy: 0.6458
# Epoch 140/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.0342 - accuracy: 0.9922 - val_loss: 2.0565 - val_accuracy: 0.6250
# Epoch 141/3000
# 25/25 [==============================] - 5s 197ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 2.1468 - val_accuracy: 0.5938
# Epoch 142/3000
# 25/25 [==============================] - 5s 203ms/step - loss: 0.1191 - accuracy: 0.9819 - val_loss: 2.6100 - val_accuracy: 0.5938
# Epoch 143/3000
# 25/25 [==============================] - 5s 203ms/step - loss: 0.0559 - accuracy: 0.9793 - val_loss: 2.1598 - val_accuracy: 0.5729
# Epoch 144/3000
# 25/25 [==============================] - 5s 215ms/step - loss: 0.0860 - accuracy: 0.9754 - val_loss: 2.5332 - val_accuracy: 0.5938
# Epoch 145/3000
# 25/25 [==============================] - 5s 209ms/step - loss: 0.2097 - accuracy: 0.9417 - val_loss: 2.4881 - val_accuracy: 0.6250
# Epoch 146/3000
# 25/25 [==============================] - 5s 214ms/step - loss: 0.2080 - accuracy: 0.9482 - val_loss: 2.8021 - val_accuracy: 0.5729
# Epoch 147/3000
# 25/25 [==============================] - 5s 215ms/step - loss: 0.0722 - accuracy: 0.9767 - val_loss: 1.6976 - val_accuracy: 0.7188
# Epoch 148/3000
# 25/25 [==============================] - 5s 209ms/step - loss: 0.1044 - accuracy: 0.9780 - val_loss: 1.8224 - val_accuracy: 0.6458
# Epoch 149/3000
# 25/25 [==============================] - 5s 201ms/step - loss: 0.0790 - accuracy: 0.9780 - val_loss: 3.0901 - val_accuracy: 0.5521
# Epoch 150/3000
# 25/25 [==============================] - 5s 209ms/step - loss: 0.0883 - accuracy: 0.9858 - val_loss: 3.4834 - val_accuracy: 0.5938
# Epoch 151/3000
# 25/25 [==============================] - 5s 210ms/step - loss: 0.0641 - accuracy: 0.9780 - val_loss: 2.6290 - val_accuracy: 0.5521
# Epoch 152/3000
# 25/25 [==============================] - 5s 215ms/step - loss: 0.0299 - accuracy: 0.9883 - val_loss: 1.8559 - val_accuracy: 0.6875
# Epoch 153/3000
# 25/25 [==============================] - 5s 212ms/step - loss: 0.0219 - accuracy: 0.9948 - val_loss: 2.8239 - val_accuracy: 0.6250
# Epoch 154/3000
# 25/25 [==============================] - 5s 208ms/step - loss: 0.0711 - accuracy: 0.9935 - val_loss: 1.5997 - val_accuracy: 0.7396
# Epoch 155/3000
# 25/25 [==============================] - 5s 211ms/step - loss: 0.0467 - accuracy: 0.9780 - val_loss: 1.9432 - val_accuracy: 0.6562
# Epoch 156/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.0143 - accuracy: 0.9961 - val_loss: 2.6787 - val_accuracy: 0.6146
# Epoch 157/3000
# 25/25 [==============================] - 5s 217ms/step - loss: 0.0096 - accuracy: 0.9962 - val_loss: 1.9598 - val_accuracy: 0.6667
# Epoch 158/3000
# 25/25 [==============================] - 5s 214ms/step - loss: 0.0147 - accuracy: 0.9974 - val_loss: 2.2795 - val_accuracy: 0.6354
# Epoch 159/3000
# 25/25 [==============================] - 5s 211ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 2.3282 - val_accuracy: 0.6146
# Epoch 160/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.1973 - accuracy: 0.9534 - val_loss: 2.0220 - val_accuracy: 0.6458
# Epoch 161/3000
# 25/25 [==============================] - 5s 211ms/step - loss: 0.1138 - accuracy: 0.9883 - val_loss: 2.1632 - val_accuracy: 0.6562
# Epoch 162/3000
# 25/25 [==============================] - 5s 201ms/step - loss: 0.0162 - accuracy: 0.9961 - val_loss: 2.0209 - val_accuracy: 0.6250
# Epoch 163/3000
# 25/25 [==============================] - 5s 203ms/step - loss: 0.1044 - accuracy: 0.9767 - val_loss: 2.3818 - val_accuracy: 0.5729
# Epoch 164/3000
# 25/25 [==============================] - 5s 203ms/step - loss: 0.0541 - accuracy: 0.9845 - val_loss: 2.1498 - val_accuracy: 0.6667
# Epoch 165/3000
# 25/25 [==============================] - 5s 201ms/step - loss: 0.1116 - accuracy: 0.9676 - val_loss: 2.4799 - val_accuracy: 0.6771
# Epoch 166/3000
# 25/25 [==============================] - 5s 198ms/step - loss: 0.2271 - accuracy: 0.9456 - val_loss: 2.9740 - val_accuracy: 0.6042
# Epoch 167/3000
# 25/25 [==============================] - 5s 210ms/step - loss: 0.0258 - accuracy: 0.9909 - val_loss: 2.1515 - val_accuracy: 0.6146
# Epoch 168/3000
# 25/25 [==============================] - 5s 200ms/step - loss: 0.5357 - accuracy: 0.9080 - val_loss: 4.2440 - val_accuracy: 0.5417
# Epoch 169/3000
# 25/25 [==============================] - 5s 210ms/step - loss: 0.3814 - accuracy: 0.9443 - val_loss: 2.0504 - val_accuracy: 0.6354
# Epoch 170/3000
# 25/25 [==============================] - 5s 201ms/step - loss: 0.3712 - accuracy: 0.9275 - val_loss: 2.3963 - val_accuracy: 0.5417
# Epoch 171/3000
# 25/25 [==============================] - 5s 200ms/step - loss: 0.1110 - accuracy: 0.9624 - val_loss: 2.3369 - val_accuracy: 0.6458
# Epoch 172/3000
# 25/25 [==============================] - 5s 212ms/step - loss: 0.1570 - accuracy: 0.9650 - val_loss: 2.3998 - val_accuracy: 0.6146
# Epoch 173/3000
# 25/25 [==============================] - 5s 204ms/step - loss: 0.0411 - accuracy: 0.9870 - val_loss: 2.3483 - val_accuracy: 0.6146
# Epoch 174/3000
# 25/25 [==============================] - 5s 209ms/step - loss: 0.0078 - accuracy: 0.9974 - val_loss: 2.2259 - val_accuracy: 0.5833
# Epoch 175/3000
# 25/25 [==============================] - 5s 208ms/step - loss: 0.0055 - accuracy: 0.9987 - val_loss: 1.9271 - val_accuracy: 0.6667
# Epoch 176/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.0254 - accuracy: 0.9987 - val_loss: 2.0622 - val_accuracy: 0.5833
# Epoch 177/3000
# 25/25 [==============================] - 5s 208ms/step - loss: 0.0585 - accuracy: 0.9780 - val_loss: 2.5916 - val_accuracy: 0.5833
# Epoch 178/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.0105 - accuracy: 0.9974 - val_loss: 1.9679 - val_accuracy: 0.6250
# Epoch 179/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.0447 - accuracy: 0.9961 - val_loss: 4.1593 - val_accuracy: 0.4167
# Epoch 180/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.1822 - accuracy: 0.9780 - val_loss: 1.5265 - val_accuracy: 0.6979
# Epoch 181/3000
# 25/25 [==============================] - 5s 209ms/step - loss: 0.0664 - accuracy: 0.9767 - val_loss: 2.6737 - val_accuracy: 0.5938
# Epoch 182/3000
# 25/25 [==============================] - 5s 202ms/step - loss: 0.0200 - accuracy: 0.9974 - val_loss: 2.3777 - val_accuracy: 0.5938
# Epoch 183/3000
# 25/25 [==============================] - 5s 215ms/step - loss: 0.0506 - accuracy: 0.9862 - val_loss: 3.1348 - val_accuracy: 0.5208
# Epoch 184/3000
# 25/25 [==============================] - 5s 213ms/step - loss: 0.0092 - accuracy: 0.9974 - val_loss: 2.3103 - val_accuracy: 0.6146
# Epoch 185/3000
# 25/25 [==============================] - 5s 204ms/step - loss: 0.0139 - accuracy: 0.9961 - val_loss: 2.2667 - val_accuracy: 0.6042
# Epoch 186/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.0139 - accuracy: 0.9974 - val_loss: 1.8435 - val_accuracy: 0.6042
# Epoch 187/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.0344 - accuracy: 0.9909 - val_loss: 2.4698 - val_accuracy: 0.5938
# Epoch 188/3000
# 25/25 [==============================] - 5s 208ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 2.4875 - val_accuracy: 0.6250
# Epoch 189/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.0334 - accuracy: 0.9909 - val_loss: 2.3610 - val_accuracy: 0.6354
# Epoch 190/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.0092 - accuracy: 0.9987 - val_loss: 2.4891 - val_accuracy: 0.5938
# Epoch 191/3000
# 25/25 [==============================] - 5s 208ms/step - loss: 0.5131 - accuracy: 0.8873 - val_loss: 3.2271 - val_accuracy: 0.6250
# Epoch 192/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.0648 - accuracy: 0.9883 - val_loss: 2.1493 - val_accuracy: 0.6562
# Epoch 193/3000
# 25/25 [==============================] - 5s 210ms/step - loss: 0.0162 - accuracy: 0.9961 - val_loss: 1.6501 - val_accuracy: 0.6771
# Epoch 194/3000
# 25/25 [==============================] - 5s 202ms/step - loss: 0.0074 - accuracy: 0.9974 - val_loss: 2.5024 - val_accuracy: 0.5729
# Epoch 195/3000
# 25/25 [==============================] - 5s 199ms/step - loss: 0.2867 - accuracy: 0.9508 - val_loss: 2.6737 - val_accuracy: 0.5729
# Epoch 196/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.2033 - accuracy: 0.9689 - val_loss: 1.9501 - val_accuracy: 0.6875
# Epoch 197/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.2685 - accuracy: 0.9560 - val_loss: 1.5151 - val_accuracy: 0.6875
# Epoch 198/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.0826 - accuracy: 0.9793 - val_loss: 1.6831 - val_accuracy: 0.6771
# Epoch 199/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.0492 - accuracy: 0.9858 - val_loss: 1.8861 - val_accuracy: 0.6458
# Epoch 200/3000
# 25/25 [==============================] - 5s 204ms/step - loss: 0.0166 - accuracy: 0.9961 - val_loss: 2.8092 - val_accuracy: 0.5625
# Epoch 201/3000
# 25/25 [==============================] - 5s 208ms/step - loss: 0.0114 - accuracy: 0.9961 - val_loss: 1.8122 - val_accuracy: 0.6771
# Epoch 202/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.9959 - val_accuracy: 0.6146
# Epoch 203/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 2.0335 - val_accuracy: 0.6354
# Epoch 204/3000
# 25/25 [==============================] - 5s 202ms/step - loss: 0.0283 - accuracy: 0.9948 - val_loss: 2.3084 - val_accuracy: 0.6667
# Epoch 205/3000
# 25/25 [==============================] - 5s 207ms/step - loss: 0.1030 - accuracy: 0.9793 - val_loss: 3.3241 - val_accuracy: 0.4688
# Epoch 206/3000
# 25/25 [==============================] - 5s 207ms/step - loss: 0.1014 - accuracy: 0.9676 - val_loss: 3.0937 - val_accuracy: 0.5312
# Epoch 207/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.0402 - accuracy: 0.9858 - val_loss: 2.4819 - val_accuracy: 0.6042
# Epoch 208/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.0411 - accuracy: 0.9974 - val_loss: 2.1326 - val_accuracy: 0.6146
# Epoch 209/3000
# 25/25 [==============================] - 5s 219ms/step - loss: 0.0447 - accuracy: 0.9862 - val_loss: 3.3114 - val_accuracy: 0.5625
# Epoch 210/3000
# 25/25 [==============================] - 5s 216ms/step - loss: 0.1114 - accuracy: 0.9883 - val_loss: 3.0628 - val_accuracy: 0.5312
# Epoch 211/3000
# 25/25 [==============================] - 5s 209ms/step - loss: 0.1197 - accuracy: 0.9832 - val_loss: 2.3246 - val_accuracy: 0.6146
# Epoch 212/3000
# 25/25 [==============================] - 5s 209ms/step - loss: 0.0868 - accuracy: 0.9741 - val_loss: 1.9431 - val_accuracy: 0.6146
# Epoch 213/3000
# 25/25 [==============================] - 5s 197ms/step - loss: 0.1661 - accuracy: 0.9663 - val_loss: 1.8693 - val_accuracy: 0.7188
# Epoch 214/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.0206 - accuracy: 0.9948 - val_loss: 2.2716 - val_accuracy: 0.6250
# Epoch 215/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.0241 - accuracy: 0.9948 - val_loss: 2.2368 - val_accuracy: 0.6250
# Epoch 216/3000
# 25/25 [==============================] - 5s 204ms/step - loss: 0.0332 - accuracy: 0.9883 - val_loss: 2.5112 - val_accuracy: 0.6250
# Epoch 217/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.0416 - accuracy: 0.9845 - val_loss: 2.2614 - val_accuracy: 0.6771
# Epoch 218/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.0100 - accuracy: 0.9974 - val_loss: 2.6759 - val_accuracy: 0.6042
# Epoch 219/3000
# 25/25 [==============================] - 5s 209ms/step - loss: 0.1090 - accuracy: 0.9689 - val_loss: 3.1511 - val_accuracy: 0.5625
# Epoch 220/3000
# 25/25 [==============================] - 5s 210ms/step - loss: 0.0182 - accuracy: 0.9922 - val_loss: 2.6081 - val_accuracy: 0.5833
# Epoch 221/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.0055 - accuracy: 0.9987 - val_loss: 2.3091 - val_accuracy: 0.6146
# Epoch 222/3000
# 25/25 [==============================] - 5s 207ms/step - loss: 0.0541 - accuracy: 0.9883 - val_loss: 3.0758 - val_accuracy: 0.5833
# Epoch 223/3000
# 25/25 [==============================] - 5s 207ms/step - loss: 0.0128 - accuracy: 0.9961 - val_loss: 2.5571 - val_accuracy: 0.6250
# Epoch 224/3000
# 25/25 [==============================] - 5s 207ms/step - loss: 0.0052 - accuracy: 0.9987 - val_loss: 2.0331 - val_accuracy: 0.6771
# Epoch 225/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.0770 - accuracy: 0.9832 - val_loss: 2.0994 - val_accuracy: 0.6458
# Epoch 226/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.0462 - accuracy: 0.9858 - val_loss: 1.9339 - val_accuracy: 0.6562
# Epoch 227/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.0723 - accuracy: 0.9896 - val_loss: 2.6869 - val_accuracy: 0.5521
# Epoch 228/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.0607 - accuracy: 0.9819 - val_loss: 2.5965 - val_accuracy: 0.6250
# Epoch 229/3000
# 25/25 [==============================] - 5s 209ms/step - loss: 0.0237 - accuracy: 0.9922 - val_loss: 2.9576 - val_accuracy: 0.5833
# Epoch 230/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 2.9657 - val_accuracy: 0.5938
# Epoch 231/3000
# 25/25 [==============================] - 5s 208ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 2.5511 - val_accuracy: 0.6250
# Epoch 232/3000
# 25/25 [==============================] - 5s 203ms/step - loss: 0.0384 - accuracy: 0.9974 - val_loss: 3.3642 - val_accuracy: 0.6042
# Epoch 233/3000
# 25/25 [==============================] - 5s 203ms/step - loss: 0.0483 - accuracy: 0.9870 - val_loss: 1.7992 - val_accuracy: 0.6354
# Epoch 234/3000
# 25/25 [==============================] - 5s 202ms/step - loss: 0.0203 - accuracy: 0.9935 - val_loss: 2.9196 - val_accuracy: 0.5938
# Epoch 235/3000
# 25/25 [==============================] - 5s 211ms/step - loss: 0.0094 - accuracy: 0.9950 - val_loss: 2.0126 - val_accuracy: 0.6667
# Epoch 236/3000
# 25/25 [==============================] - 5s 212ms/step - loss: 0.0430 - accuracy: 0.9832 - val_loss: 1.6885 - val_accuracy: 0.6458
# Epoch 237/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.2095 - accuracy: 0.9495 - val_loss: 1.9965 - val_accuracy: 0.6979
# Epoch 238/3000
# 25/25 [==============================] - 5s 208ms/step - loss: 0.1457 - accuracy: 0.9676 - val_loss: 1.5574 - val_accuracy: 0.6875
# Epoch 239/3000
# 25/25 [==============================] - 5s 207ms/step - loss: 0.0154 - accuracy: 0.9948 - val_loss: 2.4743 - val_accuracy: 0.6667
# Epoch 240/3000
# 25/25 [==============================] - 5s 207ms/step - loss: 0.0079 - accuracy: 0.9974 - val_loss: 2.5824 - val_accuracy: 0.6250
# Epoch 241/3000
# 25/25 [==============================] - 5s 209ms/step - loss: 0.0052 - accuracy: 0.9974 - val_loss: 2.2518 - val_accuracy: 0.6667
# Epoch 242/3000
# 25/25 [==============================] - 5s 207ms/step - loss: 0.1398 - accuracy: 0.9676 - val_loss: 3.4900 - val_accuracy: 0.6042
# Epoch 243/3000
# 25/25 [==============================] - 5s 209ms/step - loss: 0.0159 - accuracy: 0.9961 - val_loss: 2.8196 - val_accuracy: 0.5833
# Epoch 244/3000
# 25/25 [==============================] - 5s 207ms/step - loss: 0.0066 - accuracy: 0.9974 - val_loss: 2.1883 - val_accuracy: 0.6458
# Epoch 245/3000
# 25/25 [==============================] - 5s 210ms/step - loss: 0.0039 - accuracy: 0.9987 - val_loss: 2.3875 - val_accuracy: 0.6146
# Epoch 246/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 2.6898 - val_accuracy: 0.5938
# Epoch 247/3000
# 25/25 [==============================] - 5s 214ms/step - loss: 0.0642 - accuracy: 0.9845 - val_loss: 2.2403 - val_accuracy: 0.6771
# Epoch 248/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.3196 - accuracy: 0.9741 - val_loss: 2.1055 - val_accuracy: 0.6458
# Epoch 249/3000
# 25/25 [==============================] - 5s 209ms/step - loss: 0.0313 - accuracy: 0.9883 - val_loss: 2.9487 - val_accuracy: 0.5938
# Epoch 250/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.0267 - accuracy: 0.9935 - val_loss: 2.5513 - val_accuracy: 0.6562
# Epoch 251/3000
# 25/25 [==============================] - 5s 203ms/step - loss: 0.0184 - accuracy: 0.9935 - val_loss: 2.4182 - val_accuracy: 0.6458
# Epoch 252/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.0102 - accuracy: 0.9974 - val_loss: 2.7301 - val_accuracy: 0.5833
# Epoch 253/3000
# 25/25 [==============================] - 5s 208ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 3.0256 - val_accuracy: 0.5833
# Epoch 254/3000
# 25/25 [==============================] - 5s 204ms/step - loss: 0.0142 - accuracy: 0.9974 - val_loss: 2.8066 - val_accuracy: 0.5729
# Epoch 255/3000
# 25/25 [==============================] - 5s 199ms/step - loss: 0.0171 - accuracy: 0.9961 - val_loss: 3.0007 - val_accuracy: 0.6146
# Epoch 256/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.0409 - accuracy: 0.9883 - val_loss: 2.3008 - val_accuracy: 0.6771
# Epoch 257/3000
# 25/25 [==============================] - 5s 208ms/step - loss: 0.1130 - accuracy: 0.9935 - val_loss: 2.4126 - val_accuracy: 0.6146
# Epoch 258/3000
# 25/25 [==============================] - 5s 209ms/step - loss: 0.0513 - accuracy: 0.9832 - val_loss: 2.7321 - val_accuracy: 0.5729
# Epoch 259/3000
# 25/25 [==============================] - 5s 209ms/step - loss: 0.0808 - accuracy: 0.9974 - val_loss: 2.3861 - val_accuracy: 0.6458
# Epoch 260/3000
# 25/25 [==============================] - 5s 200ms/step - loss: 0.3619 - accuracy: 0.9430 - val_loss: 2.7335 - val_accuracy: 0.6042
# Epoch 261/3000
# 25/25 [==============================] - 5s 214ms/step - loss: 0.1306 - accuracy: 0.9463 - val_loss: 1.6074 - val_accuracy: 0.7396
# Epoch 262/3000
# 25/25 [==============================] - 5s 209ms/step - loss: 0.0067 - accuracy: 0.9974 - val_loss: 2.6169 - val_accuracy: 0.5625
# Epoch 263/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.1508 - accuracy: 0.9767 - val_loss: 2.1122 - val_accuracy: 0.6042
# Epoch 264/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.0099 - accuracy: 0.9974 - val_loss: 3.1072 - val_accuracy: 0.5729
# Epoch 265/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.0705 - accuracy: 0.9819 - val_loss: 3.2709 - val_accuracy: 0.5938
# Epoch 266/3000
# 25/25 [==============================] - 5s 210ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 2.4117 - val_accuracy: 0.6146
# Epoch 267/3000
# 25/25 [==============================] - 5s 201ms/step - loss: 0.0035 - accuracy: 0.9987 - val_loss: 2.3269 - val_accuracy: 0.6250
# Epoch 268/3000
# 25/25 [==============================] - 5s 212ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 2.2785 - val_accuracy: 0.6562
# Epoch 269/3000
# 25/25 [==============================] - 5s 210ms/step - loss: 0.0267 - accuracy: 0.9922 - val_loss: 2.5122 - val_accuracy: 0.6042
# Epoch 270/3000
# 25/25 [==============================] - 5s 202ms/step - loss: 0.0913 - accuracy: 0.9858 - val_loss: 3.3996 - val_accuracy: 0.5417
# Epoch 271/3000
# 25/25 [==============================] - 5s 199ms/step - loss: 0.1119 - accuracy: 0.9767 - val_loss: 2.3653 - val_accuracy: 0.6146
# Epoch 272/3000
# 25/25 [==============================] - 5s 204ms/step - loss: 0.0104 - accuracy: 0.9961 - val_loss: 2.3190 - val_accuracy: 0.6042
# Epoch 273/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.1030 - accuracy: 0.9845 - val_loss: 2.7836 - val_accuracy: 0.6146
# Epoch 274/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.1044 - accuracy: 0.9767 - val_loss: 3.2722 - val_accuracy: 0.5938
# Epoch 275/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.0158 - accuracy: 0.9935 - val_loss: 2.1774 - val_accuracy: 0.6250
# Epoch 276/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.4029 - accuracy: 0.9456 - val_loss: 3.1301 - val_accuracy: 0.5625
# Epoch 277/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.0567 - accuracy: 0.9819 - val_loss: 2.6550 - val_accuracy: 0.6250
# Epoch 278/3000
# 25/25 [==============================] - 5s 204ms/step - loss: 0.0642 - accuracy: 0.9858 - val_loss: 3.6809 - val_accuracy: 0.5938
# Epoch 279/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.0557 - accuracy: 0.9832 - val_loss: 2.6437 - val_accuracy: 0.6771
# Epoch 280/3000
# 25/25 [==============================] - 5s 202ms/step - loss: 0.3607 - accuracy: 0.9637 - val_loss: 1.9188 - val_accuracy: 0.6667
# Epoch 281/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.0706 - accuracy: 0.9754 - val_loss: 3.0959 - val_accuracy: 0.6354
# Epoch 282/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.0181 - accuracy: 0.9948 - val_loss: 2.3623 - val_accuracy: 0.6042
# Epoch 283/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.0089 - accuracy: 0.9987 - val_loss: 2.5221 - val_accuracy: 0.6042
# Epoch 284/3000
# 25/25 [==============================] - 5s 208ms/step - loss: 0.1185 - accuracy: 0.9922 - val_loss: 3.3302 - val_accuracy: 0.5833
# Epoch 285/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.2244 - accuracy: 0.9313 - val_loss: 3.2367 - val_accuracy: 0.5208
# Epoch 286/3000
# 25/25 [==============================] - 5s 203ms/step - loss: 0.0085 - accuracy: 0.9987 - val_loss: 2.6405 - val_accuracy: 0.6667
# Epoch 287/3000
# 25/25 [==============================] - 5s 218ms/step - loss: 0.0063 - accuracy: 0.9987 - val_loss: 2.0918 - val_accuracy: 0.6771
# Epoch 288/3000
# 25/25 [==============================] - 5s 213ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 2.2471 - val_accuracy: 0.6458
# Epoch 289/3000
# 25/25 [==============================] - 5s 208ms/step - loss: 0.0622 - accuracy: 0.9819 - val_loss: 3.6988 - val_accuracy: 0.5729
# Epoch 290/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.3072 - accuracy: 0.9430 - val_loss: 2.9642 - val_accuracy: 0.6250
# Epoch 291/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.5020 - accuracy: 0.9171 - val_loss: 1.8342 - val_accuracy: 0.6979
# Epoch 292/3000
# 25/25 [==============================] - 5s 207ms/step - loss: 0.1456 - accuracy: 0.9845 - val_loss: 2.7586 - val_accuracy: 0.6458
# Epoch 293/3000
# 25/25 [==============================] - 5s 200ms/step - loss: 0.1079 - accuracy: 0.9702 - val_loss: 2.8309 - val_accuracy: 0.6042
# Epoch 294/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.2045 - accuracy: 0.9715 - val_loss: 2.9046 - val_accuracy: 0.5938
# Epoch 295/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.0300 - accuracy: 0.9922 - val_loss: 1.8778 - val_accuracy: 0.6667
# Epoch 296/3000
# 25/25 [==============================] - 5s 207ms/step - loss: 0.0076 - accuracy: 0.9987 - val_loss: 1.8846 - val_accuracy: 0.6771
# Epoch 297/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.0144 - accuracy: 0.9948 - val_loss: 2.1075 - val_accuracy: 0.6771
# Epoch 298/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.0195 - accuracy: 0.9948 - val_loss: 2.0558 - val_accuracy: 0.6458
# Epoch 299/3000
# 25/25 [==============================] - 5s 206ms/step - loss: 0.0072 - accuracy: 0.9987 - val_loss: 2.1701 - val_accuracy: 0.6979
# Epoch 300/3000
# 25/25 [==============================] - 5s 208ms/step - loss: 0.0735 - accuracy: 0.9793 - val_loss: 2.0614 - val_accuracy: 0.6250
# Epoch 301/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.2453 - accuracy: 0.9728 - val_loss: 2.4225 - val_accuracy: 0.5938
# Epoch 302/3000
# 25/25 [==============================] - 5s 208ms/step - loss: 0.0456 - accuracy: 0.9870 - val_loss: 2.0354 - val_accuracy: 0.5938
# Epoch 303/3000
# 25/25 [==============================] - 5s 200ms/step - loss: 0.0941 - accuracy: 0.9806 - val_loss: 2.4937 - val_accuracy: 0.6042
# Epoch 304/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.1036 - accuracy: 0.9780 - val_loss: 1.8259 - val_accuracy: 0.6458
# Epoch 305/3000
# 25/25 [==============================] - 5s 209ms/step - loss: 0.0157 - accuracy: 0.9948 - val_loss: 2.2018 - val_accuracy: 0.6771
# Epoch 306/3000
# 25/25 [==============================] - 5s 209ms/step - loss: 0.0729 - accuracy: 0.9948 - val_loss: 2.7002 - val_accuracy: 0.6771
# Epoch 307/3000
# 25/25 [==============================] - 5s 210ms/step - loss: 0.0433 - accuracy: 0.9896 - val_loss: 3.2075 - val_accuracy: 0.6146
# Epoch 308/3000
# 25/25 [==============================] - 5s 209ms/step - loss: 0.0480 - accuracy: 0.9909 - val_loss: 1.8370 - val_accuracy: 0.6458
# Epoch 309/3000
# 25/25 [==============================] - 5s 207ms/step - loss: 0.1184 - accuracy: 0.9961 - val_loss: 2.9584 - val_accuracy: 0.5729
# Epoch 310/3000
# 25/25 [==============================] - 5s 200ms/step - loss: 0.1342 - accuracy: 0.9702 - val_loss: 3.2807 - val_accuracy: 0.5833
# Epoch 311/3000
# 25/25 [==============================] - 5s 202ms/step - loss: 0.1031 - accuracy: 0.9676 - val_loss: 1.9242 - val_accuracy: 0.6458
# Epoch 312/3000
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0189 - accuracy: 0.9948 - val_loss: 2.3351 - val_accuracy: 0.6458
# Epoch 313/3000
# 25/25 [==============================] - 5s 216ms/step - loss: 0.0053 - accuracy: 0.9987 - val_loss: 2.0447 - val_accuracy: 0.6771
# Epoch 314/3000
# 25/25 [==============================] - 5s 211ms/step - loss: 0.0052 - accuracy: 0.9987 - val_loss: 1.9120 - val_accuracy: 0.6667
# Epoch 315/3000
# 25/25 [==============================] - 5s 201ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.9441 - val_accuracy: 0.7188
# Epoch 316/3000
# 25/25 [==============================] - 5s 201ms/step - loss: 0.0032 - accuracy: 0.9987 - val_loss: 2.3432 - val_accuracy: 0.6562
# Epoch 317/3000
# 25/25 [==============================] - 5s 202ms/step - loss: 0.3610 - accuracy: 0.9339 - val_loss: 2.5555 - val_accuracy: 0.5938
# Epoch 318/3000
# 25/25 [==============================] - 5s 208ms/step - loss: 0.0444 - accuracy: 0.9870 - val_loss: 2.8080 - val_accuracy: 0.5625
# Epoch 319/3000
# 25/25 [==============================] - 5s 207ms/step - loss: 0.3131 - accuracy: 0.9650 - val_loss: 3.7096 - val_accuracy: 0.4479
# Epoch 320/3000
# 25/25 [==============================] - 5s 204ms/step - loss: 0.0210 - accuracy: 0.9948 - val_loss: 2.3346 - val_accuracy: 0.6354
# Epoch 321/3000
# 25/25 [==============================] - 5s 199ms/step - loss: 0.0309 - accuracy: 0.9935 - val_loss: 2.1533 - val_accuracy: 0.6562
# Epoch 322/3000
# 25/25 [==============================] - 5s 200ms/step - loss: 0.1040 - accuracy: 0.9754 - val_loss: 2.8531 - val_accuracy: 0.5729
# Epoch 323/3000
# 25/25 [==============================] - 5s 201ms/step - loss: 0.0191 - accuracy: 0.9909 - val_loss: 2.6425 - val_accuracy: 0.6042
# Epoch 324/3000
# 25/25 [==============================] - 5s 200ms/step - loss: 0.0051 - accuracy: 0.9974 - val_loss: 2.5711 - val_accuracy: 0.6042
# Epoch 325/3000
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 2.4519 - val_accuracy: 0.6146
# Epoch 326/3000
# 25/25 [==============================] - 5s 200ms/step - loss: 0.0035 - accuracy: 0.9987 - val_loss: 2.5345 - val_accuracy: 0.5625
# Epoch 327/3000
# 25/25 [==============================] - 5s 199ms/step - loss: 0.0246 - accuracy: 0.9922 - val_loss: 2.2617 - val_accuracy: 0.6458
# Epoch 328/3000
# 25/25 [==============================] - 5s 199ms/step - loss: 0.0220 - accuracy: 0.9922 - val_loss: 1.9674 - val_accuracy: 0.6146
# Epoch 329/3000
# 25/25 [==============================] - 5s 200ms/step - loss: 0.0321 - accuracy: 0.9909 - val_loss: 1.9744 - val_accuracy: 0.6250
# Epoch 330/3000
# ...
# 25/25 [==============================] - 5s 203ms/step - loss: 0.0523 - accuracy: 0.9896 - val_loss: 6.0171 - val_accuracy: 0.6250
# Epoch 2332/3000
# 25/25 [==============================] - 5s 209ms/step - loss: 9.3741e-04 - accuracy: 1.0000 - val_loss: 5.4207 - val_accuracy: 0.6667
# Epoch 2333/3000
# 25/25 [==============================] - 5s 204ms/step - loss: 0.0044 - accuracy: 0.9987 - val_loss: 4.8737 - val_accuracy: 0.6562
# Epoch 2334/3000
# 25/25 [==============================] - 5s 207ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 4.3171 - val_accuracy: 0.6667
# Epoch 2335/3000
# 25/25 [==============================] - 5s 208ms/step - loss: 0.0815 - accuracy: 0.9987 - val_loss: 6.0660 - val_accuracy: 0.5833
# Epoch 2336/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.1161 - accuracy: 0.9922 - val_loss: 5.9775 - val_accuracy: 0.6146
# Epoch 2337/3000
# 25/25 [==============================] - 5s 205ms/step - loss: 0.1372 - accuracy: 0.9948 - val_loss: 9.0877 - val_accuracy: 0.5729
# Epoch 2338/3000
# 25/25 [==============================] - 5s 204ms/step - loss: 0.0453 - accuracy: 0.9858 - val_loss: 5.3864 - val_accuracy: 0.6146
# Epoch 2339/3000
# 25/25 [==============================] - 5s 204ms/step - loss: 0.0047 - accuracy: 0.9987 - val_loss: 4.0491 - val_accuracy: 0.6875
# Epoch 2340/3000
# 25/25 [==============================] - 5s 200ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 4.4100 - val_accuracy: 0.6667
# Epoch 2341/3000
# 25/25 [==============================] - 5s 212ms/step - loss: 9.3655e-04 - accuracy: 1.0000 - val_loss: 4.5337 - val_accuracy: 0.6562
# Epoch 2342/3000
# 25/25 [==============================] - 5s 203ms/step - loss: 9.9108e-04 - accuracy: 1.0000 - val_loss: 4.0241 - val_accuracy: 0.6667
# Epoch 2343/3000
# 25/25 [==============================] - 5s 207ms/step - loss: 9.3365e-04 - accuracy: 1.0000 - val_loss: 4.3102 - val_accuracy: 0.6667
# Epoch 2344/3000
# 25/25 [==============================] - 6s 227ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 4.5906 - val_accuracy: 0.6458
# Epoch 2345/3000
# 25/25 [==============================] - 5s 217ms/step - loss: 0.0029 - accuracy: 0.9987 - val_loss: 4.5637 - val_accuracy: 0.6458
# Epoch 2346/3000
# 25/25 [==============================] - 5s 216ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 4.5981 - val_accuracy: 0.6562
# Epoch 2347/3000
# 25/25 [==============================] - 5s 214ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 5.6759 - val_accuracy: 0.6354
# Epoch 2348/3000
# 25/25 [==============================] - 6s 220ms/step - loss: 0.6066 - accuracy: 0.9560 - val_loss: 3.6777 - val_accuracy: 0.6562
# Epoch 2349/3000
# 25/25 [==============================] - 5s 220ms/step - loss: 0.0194 - accuracy: 0.9961 - val_loss: 6.0421 - val_accuracy: 0.6146
# Epoch 2350/3000
# 25/25 [==============================] - 5s 219ms/step - loss: 0.0031 - accuracy: 0.9987 - val_loss: 5.7406 - val_accuracy: 0.5938
# Epoch 2351/3000
# 25/25 [==============================] - 6s 222ms/step - loss: 9.3518e-04 - accuracy: 1.0000 - val_loss: 5.0110 - val_accuracy: 0.6250
# Epoch 2352/3000
# 25/25 [==============================] - 5s 220ms/step - loss: 9.3499e-04 - accuracy: 1.0000 - val_loss: 5.1561 - val_accuracy: 0.6250
# Epoch 2353/3000
# 25/25 [==============================] - 5s 214ms/step - loss: 0.1123 - accuracy: 0.9987 - val_loss: 6.0502 - val_accuracy: 0.5833
# Epoch 2354/3000
# 25/25 [==============================] - 5s 216ms/step - loss: 0.0628 - accuracy: 0.9935 - val_loss: 3.2482 - val_accuracy: 0.7500
# Epoch 2355/3000
# 25/25 [==============================] - 5s 216ms/step - loss: 0.0160 - accuracy: 0.9922 - val_loss: 3.3824 - val_accuracy: 0.7396
# Epoch 2356/3000
# 25/25 [==============================] - 5s 209ms/step - loss: 9.4400e-04 - accuracy: 1.0000 - val_loss: 3.7796 - val_accuracy: 0.7396
# Epoch 2357/3000
# 25/25 [==============================] - 5s 216ms/step - loss: 0.0653 - accuracy: 0.9987 - val_loss: 3.9016 - val_accuracy: 0.7083
# Epoch 2358/3000
# 25/25 [==============================] - 5s 218ms/step - loss: 0.0257 - accuracy: 0.9896 - val_loss: 3.9027 - val_accuracy: 0.6771
# Epoch 2359/3000
# 25/25 [==============================] - 6s 221ms/step - loss: 0.2469 - accuracy: 0.9948 - val_loss: 3.7764 - val_accuracy: 0.6875
# Epoch 2360/3000
# 25/25 [==============================] - 5s 211ms/step - loss: 0.1424 - accuracy: 0.9870 - val_loss: 5.1722 - val_accuracy: 0.6042
# Epoch 2361/3000
# 25/25 [==============================] - 5s 215ms/step - loss: 0.0134 - accuracy: 0.9974 - val_loss: 5.7114 - val_accuracy: 0.5521
# Epoch 2362/3000
# 25/25 [==============================] - 5s 216ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 4.5708 - val_accuracy: 0.5833
# Epoch 2363/3000
# 25/25 [==============================] - 5s 219ms/step - loss: 0.0722 - accuracy: 0.9987 - val_loss: 4.3022 - val_accuracy: 0.6562
# Epoch 2364/3000
# 25/25 [==============================] - 5s 215ms/step - loss: 0.0680 - accuracy: 0.9832 - val_loss: 4.9244 - val_accuracy: 0.6667
# Epoch 2365/3000
# 25/25 [==============================] - 5s 216ms/step - loss: 9.4657e-04 - accuracy: 1.0000 - val_loss: 6.5073 - val_accuracy: 0.6042
# Epoch 2366/3000
# 25/25 [==============================] - 5s 217ms/step - loss: 0.0098 - accuracy: 0.9987 - val_loss: 5.8079 - val_accuracy: 0.6354
# Epoch 2367/3000
# 25/25 [==============================] - 6s 237ms/step - loss: 9.3570e-04 - accuracy: 1.0000 - val_loss: 5.4287 - val_accuracy: 0.6458
# Epoch 2368/3000
# 25/25 [==============================] - 6s 232ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 5.1745 - val_accuracy: 0.6667
# Epoch 2369/3000
# 25/25 [==============================] - 6s 253ms/step - loss: 9.4779e-04 - accuracy: 1.0000 - val_loss: 5.1292 - val_accuracy: 0.6667
# Epoch 2370/3000
# 25/25 [==============================] - 6s 245ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 5.0837 - val_accuracy: 0.6562
# Epoch 2371/3000
# 25/25 [==============================] - 6s 239ms/step - loss: 9.3524e-04 - accuracy: 1.0000 - val_loss: 5.1297 - val_accuracy: 0.6458
# Epoch 2372/3000
# 25/25 [==============================] - 6s 235ms/step - loss: 9.3536e-04 - accuracy: 1.0000 - val_loss: 4.9549 - val_accuracy: 0.6562
# Epoch 2373/3000
# 25/25 [==============================] - 6s 228ms/step - loss: 0.0180 - accuracy: 0.9961 - val_loss: 5.3435 - val_accuracy: 0.7083
# Epoch 2374/3000
# 25/25 [==============================] - 5s 210ms/step - loss: 0.0570 - accuracy: 0.9922 - val_loss: 2.5952 - val_accuracy: 0.7500
# Epoch 2375/3000
# 25/25 [==============================] - 6s 226ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 3.3919 - val_accuracy: 0.7083
# Epoch 2376/3000
# 25/25 [==============================] - 6s 244ms/step - loss: 9.4486e-04 - accuracy: 1.0000 - val_loss: 3.7616 - val_accuracy: 0.6875
# Epoch 2377/3000
# 25/25 [==============================] - 6s 247ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 3.8191 - val_accuracy: 0.6771
# Epoch 2378/3000
# 25/25 [==============================] - 6s 230ms/step - loss: 0.0814 - accuracy: 0.9987 - val_loss: 6.5940 - val_accuracy: 0.5208
# Epoch 2379/3000
# 25/25 [==============================] - 6s 231ms/step - loss: 0.0537 - accuracy: 0.9935 - val_loss: 9.5827 - val_accuracy: 0.5417
# Epoch 2380/3000
# 25/25 [==============================] - 6s 226ms/step - loss: 0.3370 - accuracy: 0.9845 - val_loss: 4.1544 - val_accuracy: 0.6562
# Epoch 2381/3000
# 25/25 [==============================] - 6s 224ms/step - loss: 0.1450 - accuracy: 0.9909 - val_loss: 3.7847 - val_accuracy: 0.6875
# Epoch 2382/3000
# 25/25 [==============================] - 6s 226ms/step - loss: 0.0402 - accuracy: 0.9922 - val_loss: 3.4971 - val_accuracy: 0.6979
# Epoch 2383/3000
# 25/25 [==============================] - 6s 226ms/step - loss: 9.4600e-04 - accuracy: 1.0000 - val_loss: 3.8744 - val_accuracy: 0.6875
# Epoch 2384/3000
# 25/25 [==============================] - 5s 216ms/step - loss: 0.0332 - accuracy: 0.9974 - val_loss: 3.8360 - val_accuracy: 0.6771
# Epoch 2385/3000
# 25/25 [==============================] - 6s 222ms/step - loss: 0.1015 - accuracy: 0.9935 - val_loss: 4.0277 - val_accuracy: 0.6458
# Epoch 2386/3000
# 25/25 [==============================] - 6s 222ms/step - loss: 0.0545 - accuracy: 0.9948 - val_loss: 3.8698 - val_accuracy: 0.6875
# Epoch 2387/3000
# 25/25 [==============================] - 6s 221ms/step - loss: 0.0087 - accuracy: 0.9987 - val_loss: 3.6300 - val_accuracy: 0.7500
# Epoch 2388/3000
# 25/25 [==============================] - 5s 219ms/step - loss: 0.0783 - accuracy: 0.9922 - val_loss: 8.9585 - val_accuracy: 0.6042
# Epoch 2389/3000
# 25/25 [==============================] - 5s 219ms/step - loss: 0.2067 - accuracy: 0.9754 - val_loss: 3.6145 - val_accuracy: 0.6771
# Epoch 2390/3000
# 25/25 [==============================] - 6s 220ms/step - loss: 0.0294 - accuracy: 0.9961 - val_loss: 3.1992 - val_accuracy: 0.6875
# Epoch 2391/3000
# 25/25 [==============================] - 5s 219ms/step - loss: 0.0062 - accuracy: 0.9987 - val_loss: 3.0496 - val_accuracy: 0.6979
# Epoch 2392/3000
# 25/25 [==============================] - 5s 213ms/step - loss: 0.0049 - accuracy: 0.9987 - val_loss: 3.3422 - val_accuracy: 0.7188
# Epoch 2393/3000
# 25/25 [==============================] - 6s 230ms/step - loss: 9.4115e-04 - accuracy: 1.0000 - val_loss: 3.1071 - val_accuracy: 0.7292
# Epoch 2394/3000
# 25/25 [==============================] - 6s 230ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 3.7799 - val_accuracy: 0.7083
# Epoch 2395/3000
# 25/25 [==============================] - 6s 223ms/step - loss: 9.4991e-04 - accuracy: 1.0000 - val_loss: 4.1186 - val_accuracy: 0.6875
# Epoch 2396/3000
# 25/25 [==============================] - 5s 220ms/step - loss: 0.1039 - accuracy: 0.9896 - val_loss: 4.0843 - val_accuracy: 0.7292
# Epoch 2397/3000
# 25/25 [==============================] - 5s 220ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 4.2263 - val_accuracy: 0.6979
# Epoch 2398/3000
# 25/25 [==============================] - 6s 221ms/step - loss: 0.1864 - accuracy: 0.9896 - val_loss: 6.1960 - val_accuracy: 0.6562
# Epoch 2399/3000
# 25/25 [==============================] - 5s 213ms/step - loss: 0.0869 - accuracy: 0.9935 - val_loss: 3.0056 - val_accuracy: 0.7188
# Epoch 2400/3000
# 25/25 [==============================] - 6s 233ms/step - loss: 0.2514 - accuracy: 0.9974 - val_loss: 6.3659 - val_accuracy: 0.5938
# Epoch 2401/3000
# 25/25 [==============================] - 6s 221ms/step - loss: 0.0052 - accuracy: 0.9974 - val_loss: 5.4148 - val_accuracy: 0.6354
# Epoch 2402/3000
# 25/25 [==============================] - 6s 239ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 5.1758 - val_accuracy: 0.6250
# Epoch 2403/3000
# 25/25 [==============================] - 6s 225ms/step - loss: 0.0126 - accuracy: 0.9987 - val_loss: 2.9755 - val_accuracy: 0.7396
# Epoch 2404/3000
# 25/25 [==============================] - 5s 217ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 3.2137 - val_accuracy: 0.7292
# Epoch 2405/3000
# 25/25 [==============================] - 6s 237ms/step - loss: 0.0028 - accuracy: 0.9987 - val_loss: 3.5544 - val_accuracy: 0.7292
# Epoch 2406/3000
# 25/25 [==============================] - 5s 217ms/step - loss: 0.0389 - accuracy: 0.9974 - val_loss: 6.9488 - val_accuracy: 0.5000
# Epoch 2407/3000
# 25/25 [==============================] - 6s 225ms/step - loss: 0.4285 - accuracy: 0.9858 - val_loss: 8.8024 - val_accuracy: 0.5625
# Epoch 2408/3000
# 25/25 [==============================] - 6s 224ms/step - loss: 0.1333 - accuracy: 0.9819 - val_loss: 8.6035 - val_accuracy: 0.6146
# Epoch 2409/3000
# 25/25 [==============================] - 6s 226ms/step - loss: 0.0458 - accuracy: 0.9922 - val_loss: 5.4414 - val_accuracy: 0.6146
# Epoch 2410/3000
# 25/25 [==============================] - 5s 214ms/step - loss: 9.4712e-04 - accuracy: 1.0000 - val_loss: 5.0549 - val_accuracy: 0.6458
# Epoch 2411/3000
# 25/25 [==============================] - 6s 223ms/step - loss: 0.0217 - accuracy: 0.9987 - val_loss: 3.2263 - val_accuracy: 0.6875
# Epoch 2412/3000
# 25/25 [==============================] - 5s 217ms/step - loss: 0.0463 - accuracy: 0.9909 - val_loss: 3.6992 - val_accuracy: 0.6875
# Epoch 2413/3000
# 25/25 [==============================] - 5s 218ms/step - loss: 9.4885e-04 - accuracy: 1.0000 - val_loss: 4.0677 - val_accuracy: 0.6667
# Epoch 2414/3000
# 25/25 [==============================] - 5s 217ms/step - loss: 9.7999e-04 - accuracy: 1.0000 - val_loss: 4.0080 - val_accuracy: 0.6562
# Epoch 2415/3000
# 25/25 [==============================] - 5s 217ms/step - loss: 9.4511e-04 - accuracy: 1.0000 - val_loss: 4.0612 - val_accuracy: 0.6562
# Epoch 2416/3000
# 25/25 [==============================] - 5s 216ms/step - loss: 9.4343e-04 - accuracy: 1.0000 - val_loss: 4.1606 - val_accuracy: 0.6562
# Epoch 2417/3000
# 25/25 [==============================] - 5s 220ms/step - loss: 0.0186 - accuracy: 0.9987 - val_loss: 4.5195 - val_accuracy: 0.6458
# Epoch 2418/3000
# 25/25 [==============================] - 5s 218ms/step - loss: 0.0177 - accuracy: 0.9935 - val_loss: 4.5274 - val_accuracy: 0.6354
# Epoch 2419/3000
# 25/25 [==============================] - 6s 227ms/step - loss: 9.4409e-04 - accuracy: 1.0000 - val_loss: 4.0725 - val_accuracy: 0.6458
# Epoch 2420/3000
# 25/25 [==============================] - 6s 228ms/step - loss: 9.5166e-04 - accuracy: 1.0000 - val_loss: 4.5095 - val_accuracy: 0.6250
# Epoch 2421/3000
# 25/25 [==============================] - 5s 220ms/step - loss: 9.4952e-04 - accuracy: 1.0000 - val_loss: 4.3556 - val_accuracy: 0.6146
# Epoch 2422/3000
# 25/25 [==============================] - 6s 222ms/step - loss: 0.3791 - accuracy: 0.9767 - val_loss: 5.8082 - val_accuracy: 0.5833
# Epoch 2423/3000
# 25/25 [==============================] - 6s 220ms/step - loss: 0.3389 - accuracy: 0.9832 - val_loss: 4.4739 - val_accuracy: 0.6250
# Epoch 2424/3000
# 25/25 [==============================] - 5s 218ms/step - loss: 9.6514e-04 - accuracy: 1.0000 - val_loss: 4.5668 - val_accuracy: 0.6354
# Epoch 2425/3000
# 25/25 [==============================] - 5s 215ms/step - loss: 9.6545e-04 - accuracy: 1.0000 - val_loss: 4.7568 - val_accuracy: 0.6354
# Epoch 2426/3000
# 25/25 [==============================] - 5s 215ms/step - loss: 9.4478e-04 - accuracy: 1.0000 - val_loss: 4.7545 - val_accuracy: 0.6458
# Epoch 2427/3000
# 25/25 [==============================] - 5s 215ms/step - loss: 0.0554 - accuracy: 0.9987 - val_loss: 4.5574 - val_accuracy: 0.6979
# Epoch 2428/3000
# 25/25 [==============================] - 5s 209ms/step - loss: 0.0845 - accuracy: 0.9987 - val_loss: 5.0207 - val_accuracy: 0.6458
# Epoch 2429/3000
# 25/25 [==============================] - 6s 222ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 5.3512 - val_accuracy: 0.6146
# Epoch 2430/3000
# 25/25 [==============================] - 6s 221ms/step - loss: 9.4668e-04 - accuracy: 1.0000 - val_loss: 5.5562 - val_accuracy: 0.6042
# Epoch 2431/3000
# 25/25 [==============================] - 6s 224ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 5.3890 - val_accuracy: 0.6042
# Epoch 2432/3000
# 25/25 [==============================] - 6s 233ms/step - loss: 0.1014 - accuracy: 0.9987 - val_loss: 3.1482 - val_accuracy: 0.7188
# Epoch 2433/3000
# 25/25 [==============================] - 6s 234ms/step - loss: 0.0141 - accuracy: 0.9961 - val_loss: 3.0789 - val_accuracy: 0.6979
# Epoch 2434/3000
# 25/25 [==============================] - 6s 222ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 2.9624 - val_accuracy: 0.7083
# Epoch 2435/3000
# 25/25 [==============================] - 6s 224ms/step - loss: 9.4783e-04 - accuracy: 1.0000 - val_loss: 3.4960 - val_accuracy: 0.6875
# Epoch 2436/3000
# 25/25 [==============================] - 6s 222ms/step - loss: 0.0420 - accuracy: 0.9987 - val_loss: 6.7673 - val_accuracy: 0.5938
# Epoch 2437/3000
# 25/25 [==============================] - 6s 221ms/step - loss: 0.0407 - accuracy: 0.9935 - val_loss: 4.3539 - val_accuracy: 0.6875
# Epoch 2438/3000
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000Buffered data was truncated after reaching the output size limit.

# %%
import matplotlib.pyplot as plt


# Plot training & validation accuracy values
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.ylim(0.3, 1.1)
plt.show()

# Plot training & validation loss values
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.ylim(0,2)
plt.show()

# %%
import numpy as np

x_data = []
y_data = []
for x, y in test_data.repeat(1):
    x_data.append(x)
    y_data.append(y)

x_data = np.vstack(x_data).reshape(-1,224,224,3)
predictions = model.predict_classes(x_data)

for i in range(len(y_data)):
    print(y_data[i], predictions[i], 'x' if list(y_data[i]).index(1) == predictions[i] else '' )
# Out:
# tf.Tensor([0. 1. 0. 0. 0.], shape=(5,), dtype=float32) 2
# tf.Tensor([0. 1. 0. 0. 0.], shape=(5,), dtype=float32) 2
# tf.Tensor([0. 1. 0. 0. 0.], shape=(5,), dtype=float32) 1 x
# tf.Tensor([0. 1. 0. 0. 0.], shape=(5,), dtype=float32) 2
# tf.Tensor([0. 1. 0. 0. 0.], shape=(5,), dtype=float32) 4
# tf.Tensor([0. 1. 0. 0. 0.], shape=(5,), dtype=float32) 0
# tf.Tensor([0. 1. 0. 0. 0.], shape=(5,), dtype=float32) 1 x
# tf.Tensor([0. 1. 0. 0. 0.], shape=(5,), dtype=float32) 4
# tf.Tensor([0. 1. 0. 0. 0.], shape=(5,), dtype=float32) 2
# tf.Tensor([0. 1. 0. 0. 0.], shape=(5,), dtype=float32) 0
# tf.Tensor([0. 1. 0. 0. 0.], shape=(5,), dtype=float32) 4
# tf.Tensor([0. 1. 0. 0. 0.], shape=(5,), dtype=float32) 2
# tf.Tensor([0. 1. 0. 0. 0.], shape=(5,), dtype=float32) 2
# tf.Tensor([0. 1. 0. 0. 0.], shape=(5,), dtype=float32) 4
# tf.Tensor([0. 1. 0. 0. 0.], shape=(5,), dtype=float32) 4
# tf.Tensor([0. 1. 0. 0. 0.], shape=(5,), dtype=float32) 4
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 2 x
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 2 x
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 2 x
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 2 x
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 2 x
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 2 x
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 0
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 2 x
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 2 x
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 2 x
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 2 x
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 2 x
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 4
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 2 x
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 2 x
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 4
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 2 x
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 2 x
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 2 x
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 2 x
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 2 x
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 4
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 2 x
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 2 x
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 2 x
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 2 x
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 2 x
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 2 x
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 2 x
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 0
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 2 x
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 4
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 2 x
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 2 x
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 0
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 2 x
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32) 2 x
# tf.Tensor([0. 0. 0. 0. 1.], shape=(5,), dtype=float32) 4 x
# tf.Tensor([0. 0. 0. 0. 1.], shape=(5,), dtype=float32) 4 x
# tf.Tensor([0. 0. 0. 0. 1.], shape=(5,), dtype=float32) 2
# tf.Tensor([0. 0. 0. 0. 1.], shape=(5,), dtype=float32) 4 x
# tf.Tensor([0. 0. 0. 0. 1.], shape=(5,), dtype=float32) 4 x
# tf.Tensor([0. 0. 0. 0. 1.], shape=(5,), dtype=float32) 4 x
# tf.Tensor([0. 0. 0. 0. 1.], shape=(5,), dtype=float32) 4 x
# tf.Tensor([0. 0. 0. 0. 1.], shape=(5,), dtype=float32) 4 x
# tf.Tensor([0. 0. 0. 0. 1.], shape=(5,), dtype=float32) 2
# tf.Tensor([0. 0. 0. 0. 1.], shape=(5,), dtype=float32) 4 x
# tf.Tensor([0. 0. 0. 0. 1.], shape=(5,), dtype=float32) 2
# tf.Tensor([0. 0. 0. 0. 1.], shape=(5,), dtype=float32) 4 x
# tf.Tensor([0. 0. 0. 0. 1.], shape=(5,), dtype=float32) 4 x
# tf.Tensor([0. 0. 0. 0. 1.], shape=(5,), dtype=float32) 4 x
# tf.Tensor([0. 0. 0. 0. 1.], shape=(5,), dtype=float32) 2
# tf.Tensor([0. 0. 0. 0. 1.], shape=(5,), dtype=float32) 4 x
# tf.Tensor([0. 0. 0. 0. 1.], shape=(5,), dtype=float32) 4 x
# tf.Tensor([0. 0. 0. 1. 0.], shape=(5,), dtype=float32) 3 x
# tf.Tensor([0. 0. 0. 1. 0.], shape=(5,), dtype=float32) 0
# tf.Tensor([0. 0. 0. 1. 0.], shape=(5,), dtype=float32) 2
# tf.Tensor([0. 0. 0. 1. 0.], shape=(5,), dtype=float32) 2
# tf.Tensor([0. 0. 0. 1. 0.], shape=(5,), dtype=float32) 2
# tf.Tensor([0. 0. 0. 1. 0.], shape=(5,), dtype=float32) 3 x
# tf.Tensor([0. 0. 0. 1. 0.], shape=(5,), dtype=float32) 3 x
# tf.Tensor([0. 0. 0. 1. 0.], shape=(5,), dtype=float32) 3 x
# tf.Tensor([0. 0. 0. 1. 0.], shape=(5,), dtype=float32) 2
# tf.Tensor([0. 0. 0. 1. 0.], shape=(5,), dtype=float32) 3 x
# tf.Tensor([0. 0. 0. 1. 0.], shape=(5,), dtype=float32) 3 x
# tf.Tensor([0. 0. 0. 1. 0.], shape=(5,), dtype=float32) 3 x
# tf.Tensor([0. 0. 0. 1. 0.], shape=(5,), dtype=float32) 3 x
# tf.Tensor([0. 0. 0. 1. 0.], shape=(5,), dtype=float32) 4
# tf.Tensor([0. 0. 0. 1. 0.], shape=(5,), dtype=float32) 3 x
# tf.Tensor([0. 0. 0. 1. 0.], shape=(5,), dtype=float32) 0
# tf.Tensor([1. 0. 0. 0. 0.], shape=(5,), dtype=float32) 0 x
# tf.Tensor([1. 0. 0. 0. 0.], shape=(5,), dtype=float32) 0 x
# tf.Tensor([1. 0. 0. 0. 0.], shape=(5,), dtype=float32) 0 x
# tf.Tensor([1. 0. 0. 0. 0.], shape=(5,), dtype=float32) 0 x
# tf.Tensor([1. 0. 0. 0. 0.], shape=(5,), dtype=float32) 0 x
# tf.Tensor([1. 0. 0. 0. 0.], shape=(5,), dtype=float32) 0 x
# tf.Tensor([1. 0. 0. 0. 0.], shape=(5,), dtype=float32) 0 x
# tf.Tensor([1. 0. 0. 0. 0.], shape=(5,), dtype=float32) 0 x
# tf.Tensor([1. 0. 0. 0. 0.], shape=(5,), dtype=float32) 0 x
# tf.Tensor([1. 0. 0. 0. 0.], shape=(5,), dtype=float32) 0 x
# tf.Tensor([1. 0. 0. 0. 0.], shape=(5,), dtype=float32) 0 x
# tf.Tensor([1. 0. 0. 0. 0.], shape=(5,), dtype=float32) 0 x
# tf.Tensor([1. 0. 0. 0. 0.], shape=(5,), dtype=float32) 0 x

# %%
model.save('drive/My Drive/Colab Notebooks/grocery-categories-v05-a.h5')
model.save_weights('drive/My Drive/Colab Notebooks/grocery-categories-v05-a.weights.h5')
